# %%
import requests as reqs
import pandas as pd
import numpy as np

url = "https://api.punkapi.com/v2/beers?page="
sess = reqs.session()

resp = sess.get(f"{url}1&per_page=80").json()
df = pd.DataFrame(resp)

cont = True
index = 2
while cont:
    resp = sess.get(f"{url}{index}&per_page=80").json()
    index += 1
    if len(resp) == 0:
        cont = False
    df = pd.concat([pd.DataFrame(resp), df], axis=0)
    # df = df.append(pd.DataFrame(resp))
df.head()
# Out:
#     id                         name             tagline first_brewed  \
# 0  321                Jinx Pale Ale  American Pale Ale.         2018
# 1  322                    Jet Trash     West Coast IPA.         2018
# 2  323     Interstate Vienna Lager.       Vienna Lager.         2018
# 3  324  Fools Gold Dortmunder Lager              Lager.         2018
# 4  325                      Zipcode            Pilsner.         2018
#
#                                          description image_url  abv   ibu  \
# 0  A new 4.7% ABV American pale ale, Jinx Pale Al...      None  4.7  35.0
# 1  A new 6.9% ABV West Coast IPA, Jet Trash is on...      None  6.9  65.0
# 2  A new 5% ABV Vienna Lager, that features in Fa...      None  5.0  25.0
# 3  A new 5.6% Dortmunder Lager, that featues in F...      None  5.6  32.0
# 4  A new 5% Pilsner, that feaures in Fanzine, our...      None  5.0  37.0
#
#    target_fg  target_og  ...  srm   ph  attenuation_level  \
# 0     1008.0     1043.0  ...  7.0  4.6               81.0
# 1     1008.0     1060.0  ...  9.0  4.6               87.0
# 2     1007.0     1045.0  ...  7.0  4.2               84.0
# 3     1009.0     1052.0  ...  6.0  4.2               83.0
# 4     1006.0     1044.0  ...  3.0  4.4               86.0
#
#                             volume                      boil_volume  \
# 0  {'value': 20, 'unit': 'litres'}  {'value': 25, 'unit': 'litres'}
# 1  {'value': 20, 'unit': 'litres'}  {'value': 25, 'unit': 'litres'}
# 2  {'value': 20, 'unit': 'litres'}  {'value': 25, 'unit': 'litres'}
# 3  {'value': 20, 'unit': 'litres'}  {'value': 25, 'unit': 'litres'}
# 4  {'value': 20, 'unit': 'litres'}  {'value': 25, 'unit': 'litres'}
#
#                                               method  \
# 0  {'mash_temp': [{'temp': {'value': 63, 'unit': ...
# 1  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 2  {'mash_temp': [{'temp': {'value': 67, 'unit': ...
# 3  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 4  {'mash_temp': [{'temp': {'value': 50, 'unit': ...
#
#                                          ingredients  \
# 0  {'malt': [{'name': 'Pale Ale', 'amount': {'val...
# 1  {'malt': [{'name': 'Pale Ale', 'amount': {'val...
# 2  {'malt': [{'name': 'Pilsner', 'amount': {'valu...
# 3  {'malt': [{'name': 'Pilsner', 'amount': {'valu...
# 4  {'malt': [{'name': 'Pilsner', 'amount': {'valu...
#
#                                         food_pairing  \
# 0  [Monterey Jack stuffed grilled jalapeños, App...
# 1        [Roast chicken, Seared steak, Crusty bread]
# 2  [Grilled chicken and steamed vegetables, Pork ...
# 3  [Seafood salad, Sweet and sour pork, Lemon dri...
# 4  [Goat's cheese salad, Pesto pasta, Lemon cookies]
#
#                                         brewers_tips  \
# 0  Rack this into a corny keg, cool it down and c...
# 1  Split this batch and try fermenting the other ...
# 2  Instead of using Pilsner, try to substitute th...
# 3  Make sure you burtonise your water as Dortmund...
# 4  Saphir hops are not widespread at the moment i...
#
#                contributed_by
# 0  John Jenkman <johnjenkman>
# 1  John Jenkman <johnjenkman>
# 2  John Jenkman <johnjenkman>
# 3  John Jenkman <johnjenkman>
# 4  John Jenkman <johnjenkman>
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['id', 'name', 'tagline', 'first_brewed', 'description', 'image_url',
#        'abv', 'ibu', 'target_fg', 'target_og', 'ebc', 'srm', 'ph',
#        'attenuation_level', 'volume', 'boil_volume', 'method', 'ingredients',
#        'food_pairing', 'brewers_tips', 'contributed_by'],
#       dtype='object')

# %%
np.max(df["abv"].values)
# df["abv"].values
# Out:
# 55.0

# %%
attn = df["attenuation_level"].values
np.average(attn[~np.isnan(attn)])
# Out:
# 80.59101851851852

# %%
df = df.sort_values(by="ibu", ascending=False)
df.head()
# Out:
#     id                                             name  \
# 74  75                         Never Mind The Anabolics
# 73  74                                        Eurotrash
# 72  73  Black Eyed King Imp - Vietnamese Coffee Edition
# 71  72                            Whisky Sour - B-Sides
# 70  71                              Pale - Russian Doll
#
#                                     tagline first_brewed  \
# 74    Performance-Enhancing India Pale Ale.      06/2012
# 73                          Belgian Blonde.      10/2009
# 72               Vietnamese Coffee Edition.      12/2014
# 71  Pilot Brew - Deconstructed Whisky Sour.      03/2015
# 70                        Nesting Hop Bomb.      08/2014
#
#                                           description  \
# 74  Never Mind the Anabolics, a 6.5% India Pale Al...
# 73  Trashy Blonde with a Belgian Twist. Clove oil,...
# 72  This is the Vietnamese Coffee Edition. At 12.7...
# 71  Deconstructed whisky sour, reconstructed as a ...
# 70  The levels of hops vary throughout the range. ...
#
#                                 image_url   abv     ibu  target_fg  target_og  \
# 74   https://images.punkapi.com/v2/75.png   6.5  1157.0     1012.0     1050.0
# 73  https://images.punkapi.com/v2/keg.png   4.1  1085.0     1010.0     1041.0
# 72   https://images.punkapi.com/v2/73.png  12.7   250.0     1038.0     1113.5
# 71  https://images.punkapi.com/v2/keg.png   7.0   250.0     1021.0     1081.0
# 70   https://images.punkapi.com/v2/71.png   4.0   250.0     1010.0     1041.0
#
#     ...    srm   ph  attenuation_level                           volume  \
# 74  ...   11.5  4.4               76.0  {'value': 20, 'unit': 'litres'}
# 73  ...    8.5  5.2               76.0  {'value': 20, 'unit': 'litres'}
# 72  ...  125.0  5.2               76.8  {'value': 20, 'unit': 'litres'}
# 71  ...    6.0  3.2               74.0  {'value': 20, 'unit': 'litres'}
# 70  ...   22.5  5.2               75.6  {'value': 20, 'unit': 'litres'}
#
#                         boil_volume  \
# 74  {'value': 25, 'unit': 'litres'}
# 73  {'value': 25, 'unit': 'litres'}
# 72  {'value': 25, 'unit': 'litres'}
# 71  {'value': 25, 'unit': 'litres'}
# 70  {'value': 25, 'unit': 'litres'}
#
#                                                method  \
# 74  {'mash_temp': [{'temp': {'value': 68, 'unit': ...
# 73  {'mash_temp': [{'temp': {'value': 66, 'unit': ...
# 72  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 71  {'mash_temp': [{'temp': {'value': 60, 'unit': ...
# 70  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
#
#                                           ingredients  \
# 74  {'malt': [{'name': 'Extra Pale - Spring Blend'...
# 73  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 72  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 71  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
# 70  {'malt': [{'name': 'Extra Pale', 'amount': {'v...
#
#                                          food_pairing  \
# 74  [Grilled chicken salad with bacon and avocado,...
# 73     [Grilled fish salad, Angelfood cake, Pad Thai]
# 72  [Bacon sandwich with brown sauce, 20hr smoked ...
# 71  [Potted fresh & smoked salmon, Spiced nut loaf...
# 70  [Roast chicken with vegetables and wild rice, ...
#
#                                          brewers_tips          contributed_by
# 74  Mix the powders into a paste before adding to ...  Sam Mason <samjbmason>
# 73  Don't be scared to let the fermentation temper...  Sam Mason <samjbmason>
# 72  Buying top notch coffee beans make a huge diff...  Sam Mason <samjbmason>
# 71                            Lemon poppyseed donuts.  Sam Mason <samjbmason>
# 70  Create balance through experimentation with th...  Sam Mason <samjbmason>
#
# [5 rows x 21 columns]

# %%
@np.vectorize
def isvalid(x):
    return not np.isnan(x) and 80 < x and x < 95

df = df[(~df["attenuation_level"].isna()) & (df["attenuation_level"]>80) & (df["attenuation_level"]<95)]
df.head()
# Out:
#     id                         name             tagline first_brewed  \
# 0  321                Jinx Pale Ale  American Pale Ale.         2018
# 1  322                    Jet Trash     West Coast IPA.         2018
# 2  323     Interstate Vienna Lager.       Vienna Lager.         2018
# 3  324  Fools Gold Dortmunder Lager              Lager.         2018
# 4  325                      Zipcode            Pilsner.         2018
#
#                                          description image_url  abv   ibu  \
# 0  A new 4.7% ABV American pale ale, Jinx Pale Al...      None  4.7  35.0
# 1  A new 6.9% ABV West Coast IPA, Jet Trash is on...      None  6.9  65.0
# 2  A new 5% ABV Vienna Lager, that features in Fa...      None  5.0  25.0
# 3  A new 5.6% Dortmunder Lager, that featues in F...      None  5.6  32.0
# 4  A new 5% Pilsner, that feaures in Fanzine, our...      None  5.0  37.0
#
#    target_fg  target_og  ...  srm   ph  attenuation_level  \
# 0     1008.0     1043.0  ...  7.0  4.6               81.0
# 1     1008.0     1060.0  ...  9.0  4.6               87.0
# 2     1007.0     1045.0  ...  7.0  4.2               84.0
# 3     1009.0     1052.0  ...  6.0  4.2               83.0
# 4     1006.0     1044.0  ...  3.0  4.4               86.0
#
#                             volume                      boil_volume  \
# 0  {'value': 20, 'unit': 'litres'}  {'value': 25, 'unit': 'litres'}
# 1  {'value': 20, 'unit': 'litres'}  {'value': 25, 'unit': 'litres'}
# 2  {'value': 20, 'unit': 'litres'}  {'value': 25, 'unit': 'litres'}
# 3  {'value': 20, 'unit': 'litres'}  {'value': 25, 'unit': 'litres'}
# 4  {'value': 20, 'unit': 'litres'}  {'value': 25, 'unit': 'litres'}
#
#                                               method  \
# 0  {'mash_temp': [{'temp': {'value': 63, 'unit': ...
# 1  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 2  {'mash_temp': [{'temp': {'value': 67, 'unit': ...
# 3  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 4  {'mash_temp': [{'temp': {'value': 50, 'unit': ...
#
#                                          ingredients  \
# 0  {'malt': [{'name': 'Pale Ale', 'amount': {'val...
# 1  {'malt': [{'name': 'Pale Ale', 'amount': {'val...
# 2  {'malt': [{'name': 'Pilsner', 'amount': {'valu...
# 3  {'malt': [{'name': 'Pilsner', 'amount': {'valu...
# 4  {'malt': [{'name': 'Pilsner', 'amount': {'valu...
#
#                                         food_pairing  \
# 0  [Monterey Jack stuffed grilled jalapeños, App...
# 1        [Roast chicken, Seared steak, Crusty bread]
# 2  [Grilled chicken and steamed vegetables, Pork ...
# 3  [Seafood salad, Sweet and sour pork, Lemon dri...
# 4  [Goat's cheese salad, Pesto pasta, Lemon cookies]
#
#                                         brewers_tips  \
# 0  Rack this into a corny keg, cool it down and c...
# 1  Split this batch and try fermenting the other ...
# 2  Instead of using Pilsner, try to substitute th...
# 3  Make sure you burtonise your water as Dortmund...
# 4  Saphir hops are not widespread at the moment i...
#
#                contributed_by
# 0  John Jenkman <johnjenkman>
# 1  John Jenkman <johnjenkman>
# 2  John Jenkman <johnjenkman>
# 3  John Jenkman <johnjenkman>
# 4  John Jenkman <johnjenkman>
#
# [5 rows x 21 columns]

# %%
df["mash_temp"] = df["method"].apply(lambda method: dict(method)["mash_temp"][0]["temp"]["value"])
df.head()
# Out:
#     id                         name             tagline first_brewed  \
# 0  321                Jinx Pale Ale  American Pale Ale.         2018
# 1  322                    Jet Trash     West Coast IPA.         2018
# 2  323     Interstate Vienna Lager.       Vienna Lager.         2018
# 3  324  Fools Gold Dortmunder Lager              Lager.         2018
# 4  325                      Zipcode            Pilsner.         2018
#
#                                          description image_url  abv   ibu  \
# 0  A new 4.7% ABV American pale ale, Jinx Pale Al...      None  4.7  35.0
# 1  A new 6.9% ABV West Coast IPA, Jet Trash is on...      None  6.9  65.0
# 2  A new 5% ABV Vienna Lager, that features in Fa...      None  5.0  25.0
# 3  A new 5.6% Dortmunder Lager, that featues in F...      None  5.6  32.0
# 4  A new 5% Pilsner, that feaures in Fanzine, our...      None  5.0  37.0
#
#    target_fg  target_og  ...   ph  attenuation_level  \
# 0     1008.0     1043.0  ...  4.6               81.0
# 1     1008.0     1060.0  ...  4.6               87.0
# 2     1007.0     1045.0  ...  4.2               84.0
# 3     1009.0     1052.0  ...  4.2               83.0
# 4     1006.0     1044.0  ...  4.4               86.0
#
#                             volume                      boil_volume  \
# 0  {'value': 20, 'unit': 'litres'}  {'value': 25, 'unit': 'litres'}
# 1  {'value': 20, 'unit': 'litres'}  {'value': 25, 'unit': 'litres'}
# 2  {'value': 20, 'unit': 'litres'}  {'value': 25, 'unit': 'litres'}
# 3  {'value': 20, 'unit': 'litres'}  {'value': 25, 'unit': 'litres'}
# 4  {'value': 20, 'unit': 'litres'}  {'value': 25, 'unit': 'litres'}
#
#                                               method  \
# 0  {'mash_temp': [{'temp': {'value': 63, 'unit': ...
# 1  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 2  {'mash_temp': [{'temp': {'value': 67, 'unit': ...
# 3  {'mash_temp': [{'temp': {'value': 65, 'unit': ...
# 4  {'mash_temp': [{'temp': {'value': 50, 'unit': ...
#
#                                          ingredients  \
# 0  {'malt': [{'name': 'Pale Ale', 'amount': {'val...
# 1  {'malt': [{'name': 'Pale Ale', 'amount': {'val...
# 2  {'malt': [{'name': 'Pilsner', 'amount': {'valu...
# 3  {'malt': [{'name': 'Pilsner', 'amount': {'valu...
# 4  {'malt': [{'name': 'Pilsner', 'amount': {'valu...
#
#                                         food_pairing  \
# 0  [Monterey Jack stuffed grilled jalapeños, App...
# 1        [Roast chicken, Seared steak, Crusty bread]
# 2  [Grilled chicken and steamed vegetables, Pork ...
# 3  [Seafood salad, Sweet and sour pork, Lemon dri...
# 4  [Goat's cheese salad, Pesto pasta, Lemon cookies]
#
#                                         brewers_tips  \
# 0  Rack this into a corny keg, cool it down and c...
# 1  Split this batch and try fermenting the other ...
# 2  Instead of using Pilsner, try to substitute th...
# 3  Make sure you burtonise your water as Dortmund...
# 4  Saphir hops are not widespread at the moment i...
#
#                contributed_by mash_temp
# 0  John Jenkman <johnjenkman>        63
# 1  John Jenkman <johnjenkman>        65
# 2  John Jenkman <johnjenkman>        67
# 3  John Jenkman <johnjenkman>        65
# 4  John Jenkman <johnjenkman>        50
#
# [5 rows x 22 columns]

# %%
list_of_foods = ["chicken", "cheese", "chocolate"]
beer_map = {}

@np.vectorize
def match_pairing(foods: list, food: str):
    out = False
    for f in foods:
        out = out or food in f.lower()
    return out

for f in list_of_foods:
    beer_map[f] = df[match_pairing(df["food_pairing"].values, f)]["name"].values.tolist()

beer_map
# Out:
# {'chicken': ['Jet Trash',
#   'Interstate Vienna Lager.',
#   'Hello My Name Is Ingrid 2016',
#   'Crew Brew',
#   'Small Batch: Dortmunder',
#   'Small Batch: Spelt & Honey Saison',
#   'Hello My Name Is Maria',
#   'Opaque Jake',
#   'Small Batch: Dry-hopped Pilsner',
#   'Neverland',
#   'Chinook - IPA Is Dead',
#   'Konnichiwa Kitsune',
#   'Simcoe',
#   'Punk IPA 2007 - 2010',
#   'International Arms Race (w/ Flying Dog)',
#   'Cult Lager',
#   'Monk Hammer',
#   'Mango And Chili Barley Wine',
#   'Citra',
#   'Hello My Name Is Päivi',
#   'HBC 366 - IPA Is Dead',
#   'Hop Rocker',
#   'Juniper Wheat Beer',
#   'Growler',
#   'Pioneer - IPA Is Dead',
#   'Berliner Weisse With Yuzu - B-Sides',
#   'Rabiator',
#   'Sorachi Ace',
#   'Dog Wired (w/8 Wired)',
#   'TM10',
#   'Mandarina Bavaria - IPA Is Dead',
#   'AB:08'],
#  'cheese': ['Zipcode',
#   'Small Batch: Rye IPA',
#   'Small Batch: Tripel',
#   'Small Batch: Mandarina Lager',
#   'Hazy Jane',
#   'Prototype Double IPA',
#   'Pina Colada Sidewalk',
#   'Hello My Name Is Agnetha',
#   'Indie Pale Ale',
#   'Hazy Jane Bourbon Barrel Aged',
#   'Hazy Jane Rye Barrel Aged',
#   'Karma Cloud',
#   '77 Lager',
#   'This. Is. Lager',
#   'Ella - IPA Is Dead',
#   'Bashah (w/ Stone Brewing Co)',
#   'Vic Secret',
#   'Punk IPA 2007 - 2010',
#   'Blitz Berliner Weisse',
#   'Hardkogt IPA',
#   'Bitch Please (w/ 3 Floyds)',
#   'Cascade, Centennial & Willamette IPA - B-Sides',
#   'Dog E',
#   'Black Hammer',
#   'Hello My Name Is Päivi',
#   'Hello My Name Is Beastie',
#   "Morag's Mojito - B-Sides",
#   'Dog Fight (w/ Flying Dog)',
#   'Growler',
#   'Born To Die',
#   'Cap Dog (w/ Cap Brewery)',
#   'Old World Russian Imperial Stout',
#   'Berliner Weisse With Yuzu - B-Sides',
#   'Mixtape 8',
#   'Berliner Weisse With Raspberries And Rhubarb - B-Sides',
#   'Hardcore IPA',
#   'Prototype 27',
#   'Mandarina Bavaria - IPA Is Dead',
#   'AB:16',
#   'AB:04'],
#  'chocolate': ['AB:21',
#   'Paradox Rye',
#   'AB:22',
#   'AB:23',
#   'Homicidal Puppet Help Desk',
#   'Pina Colada Sidewalk',
#   'Hello My Name Is Maria',
#   'Off-Duty Alien',
#   'Declassified Demi-God',
#   'Dog G',
#   'Bashah (w/ Stone Brewing Co)',
#   'Dog D',
#   'Simcoe',
#   'Tactical Nuclear Penguin',
#   'AB:11',
#   'Bitch Please (w/ 3 Floyds)',
#   'Dog E',
#   'Paradox Islay 2.0',
#   'Black Hammer',
#   'Lumberjack Stout',
#   'Chaos Theory',
#   'Black Eye Joe (w/ Stone Brewing Co)',
#   'Pioneer - IPA Is Dead',
#   'Old World Russian Imperial Stout',
#   'Black Tokyo Horizon (w/Nøgne Ø & Mikkeller)',
#   'AB:12',
#   'AB:06',
#   'Hello My Name is Vladimir',
#   'Hardcore IPA',
#   'Paradox Islay',
#   'Amarillo - IPA Is Dead',
#   'AB:08',
#   'Tokyo Rising Sun - Lowland',
#   'Hunter Foundation Pale Ale',
#   'AB:04']}

# %%
beer_intersection = set(beer_map["chicken"]).intersection(set(beer_map["chocolate"])).intersection(set(beer_map["cheese"]))
if beer_intersection:
    print(beer_intersection)
else:
    print("non of them goes with all three foods")

# beer_map["cheese"]
# Out:
# non of them goes with all three foods
